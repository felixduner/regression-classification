# %%
#Task 2
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb
from sklearn import datasets, metrics
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

#load the iris dataset
iris = datasets.load_iris()

#split data into training and test data
x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.25, random_state=0)

#creating the logistic regression, using one vs. rest multiclass classification
logisticRegr = LogisticRegression(multi_class='ovr', solver='liblinear')

#training model on train data
logisticRegr.fit(x_train, y_train)

# Making predictions on entire test data
predictions = logisticRegr.predict(x_test)

# calculate accuracy of model
score_lr = logisticRegr.score(x_test, y_test)

#creating confusion matrix
cm1 = metrics.confusion_matrix(y_test, predictions)

#plotting
plt.figure(figsize=(10,10))
sb.heatmap(cm1, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
acc_score_lr = 'Accuracy Score: {0}'.format(score_lr)
plt.title('Confusion matrix for Iris\n' + acc_score_lr, size = 12)
plt.savefig('Iris_confusion_matrix_LR.png')
plt.show()

# %%
#Task 3
# importing k-classification
from sklearn.neighbors import KNeighborsClassifier

#Creating a KNN Classifier with value 5. Uniform weight is default
knn = KNeighborsClassifier(n_neighbors=5, weights='uniform') 

#Training the model using the training sets decided in task 2
knn.fit(x_train, y_train)

#Predicting the response for test dataset
y_pred = knn.predict(x_test)

#calc. model accuracy
score_knn = metrics.accuracy_score(y_test, y_pred)

# Printing the model Accuracy
print(f'The model accuracy is: {score_knn}')
# Out:
# The model accuracy is: 0.9736842105263158

# %%
#Task 4
#Creating confusion matrix for K-nearest neighbor method
cm2 = metrics.confusion_matrix(y_test, y_pred)

#plotting
plt.figure(figsize=(9,9))
sb.heatmap(cm2, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
acc_score_knn = 'Accuracy Score: {0}'.format(score_knn)
plt.title('Confusion matrix for Iris\n' + acc_score_knn, size = 12)
plt.savefig('Iris_confusion_matrix_KNN.png')
plt.show()
